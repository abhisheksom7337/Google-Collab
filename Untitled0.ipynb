# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksom7337/Google-Collab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **21 September **

# %% [markdown]
# If else

# %%
dist=str(input("Enter the dist"))
age=int(input("Enter your age"))
std=int(input("What's Your higher Studies"))
per=float(input("Enter your percentage"))

if(dist == "Moradabad" and age >= 18 and std == 10 and per >= 70.00):
  print("Educated Person")
else:
  print("Not a Educated Person")
# Out:
# Enter the distMoradabad
# Enter your age19
# What's Your higher Studies10
# Enter your percentage90
# Educated Person

# %%
marks = int(input("Enter your marks"))
if(95<=marks<=100):
  print("Unbeatable")
elif(95>= marks >=90):
  print("Excellent Performance")
elif(90 >= marks >= 80):
    print("Good Performance")
elif(80 >= marks >= 60):
  print("Average Performance")
else:
  print("Poor Performance")
# Out:
# Enter your marks85
# Good Performance

# %%
for i in range(1,11):
  print(f"5*{i} = {5*i}")
# Out:
# 5*1 = 5
# 5*2 = 10
# 5*3 = 15
# 5*4 = 20
# 5*5 = 25
# 5*6 = 30
# 5*7 = 35
# 5*8 = 40
# 5*9 = 45
# 5*10 = 50

# %%
i = 1
while i <=10:
  print(5*i)
  i += 1
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
def myfunction():
  print("Hello World!")
myfunction()
# Out:
# Hello World!

# %%
def Hello(name):
 print(f"Hello{name}")
Hello("Abhishek")
# Out:
# HelloAbhishek

# %%
def add(a,b):
  return a+b
result = add(6,5)
print(result)
# Out:
# 11

# %%
def multiply(a,b):
  return a*b
result = multiply(5,2)
print(result)
# Out:
# 10

# %%
def calculation(a,b,c):
   return a+b*c
result = calculation(5,1,3)
print(result)
# Out:
# 8

# %%
def calculation (*args):
   return sum(args)
result = calculation(5,8,6,4,7)
print(result)
# Out:
# 30

# %%
def Average(*Salary):
    return sum(Salary)/len(Salary)
result = Average(4000,3000,40000,50000)
print(result)
# Out:
# 24250.0

# %% [markdown]
# **22 September **

# %%
List1 = [1,2,3,4,5,6,7,"Abhishek", True , 7.5]
print(List1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 'Abhishek', True, 7.5]

# %%
print(type(List1))
# Out:
# <class 'list'>

# %%
len(List1)
# Out:
# 10

# %% [markdown]
# Indexing

# %%
List1[0]
# Out:
# 1

# %%
List1[-3]
# Out:
# 'Abhishek'

# %% [markdown]
# Slicing or Ranging

# %%
List1[3:8]
# Out:
# [4, 5, 6, 7, 'Abhishek']

# %% [markdown]
# Question Practice

# %%
List1[0:4]
# Out:
# [1, 2, 3, 4]

# %%
List1[0:6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
List1[3:7]
# Out:
# [4, 5, 6, 7]

# %%
List1[1:7]
# Out:
# [2, 3, 4, 5, 6, 7]

# %% [markdown]
# After and Before

# %%
List1[5:]
# Out:
# [6, 7, 'Abhishek', True, 7.5]

# %%
List1[:3]
# Out:
# [1, 2, 3]

# %%
List1[-5:-2]
# Out:
# [6, 7, 'Abhishek']

# %% [markdown]
# Changing No in list

# %%
List1[8] = "Thakur Abhishek Som"
print(List1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 'Abhishek', 'Thakur Abhishek Som', 7.5]

# %%
List1.append("wow")
print(List1)
# Out:
# [1, 2, 3, 5, 6, 7, 'Thakur Abhishek Som', 'wow']

# %%
List1.pop()
print(List1)
# Out:
# [1, 2, 3, 5, 6, 7, 'Thakur Abhishek Som']

# %%
List2 = [9,5,8,6,7,2,3]
print(List2)
# Out:
# [9, 5, 8, 6, 7, 2, 3]

# %%
List2.sort()
print(List2)
# Out:
# [2, 3, 5, 6, 7, 8, 9]

# %%
List3 = [3,5,9,7,6,4,6,5]
print(List3)
List3.sort()
print(List3)
List3.reverse()
print(List3)
# Out:
# [3, 5, 9, 7, 6, 4, 6, 5]
# [3, 4, 5, 5, 6, 6, 7, 9]
# [9, 7, 6, 6, 5, 5, 4, 3]

# %%
List3.remove(7)
print(List3)
# Out:
# [9, 6, 6, 5, 5, 4, 3]

# %%
List2.insert(0,1)
print(List2)
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9]

# %%
A = [1,2,5,6,7,9,3,6]
print(A)
B = [7,9,7,6,5,3,1]
print(B)
C = A+B
print(C)
# Out:
# [1, 2, 5, 6, 7, 9, 3, 6]
# [7, 9, 7, 6, 5, 3, 1]
# [1, 2, 5, 6, 7, 9, 3, 6, 7, 9, 7, 6, 5, 3, 1]

# %%
List2.extend(List3)
print(List2)
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9, 9, 6, 6, 5, 5, 4, 3]

# %% [markdown]
# Tupple

# %%
Abhi = (1,5,6,7,9,3)
print(Abhi)
# Out:
# (1, 5, 6, 7, 9, 3)

# %%
Thakur = (9,94,6,7,6,7,56,7,5)
print(Thakur)
# Out:
# (9, 94, 6, 7, 6, 7, 56, 7, 5)

# %%
print(type(Abhi))
# Out:
# <class 'tuple'>

# %%
len(Abhi)
# Out:
# 6

# %%
print(Abhi[5])
# Out:
# 3

# %%
list = list(Abhi)
print(list)
# Out:
# [1, 5, 6, 7, 9, 3]

# %% [markdown]
# Set

# %%
Set1 = {5,6,7,8,9}
print(Set1)
# Out:
# {5, 6, 7, 8, 9}

# %%
Set2 = {2,5,7,9}
print(Set2)
# Out:
# {9, 2, 5, 7}

# %%
Set1.union(Set2)
# Out:
# {2, 5, 6, 7, 8, 9}

# %%
Set1.intersection(Set2)
# Out:
# {5, 7, 9}

# %%
Set1.difference(Set2)
# Out:
# {6, 8}

# %%
Set1.symmetric_difference(Set2)
# Out:
# {2, 6, 8}

# %%
Dict1 = {
    "Name" : "Abhishek",
    "Age" : 18
}
print(Dict1)
# Out:
# {'Name': 'Abhishek', 'Age': 18}

# %%
Dict1.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
Dict1.values()
# Out:
# dict_values(['Abhishek', 18])

# %%
Dict1["Name"]
# Out:
# 'Abhishek'

# %%
import numpy as np
ListA = [1,2,3,7,5,8]
print(type(ListA))
# Out:
# <class 'list'>

# %%
arr1 = np.array(ListA)
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr1[0])
# Out:
# 1
